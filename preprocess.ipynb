# %%
import tables
import os
import hdf5_getters as h5
# import json
import pandas as pd

# http://millionsongdataset.com/
MSD = './MillionSongSubset'

# http://millionsongdataset.com/lastfm/#api
LASTFM = "./lastfm_train"

# https://core.ac.uk/download/pdf/76535286.pdf
MOODY = "./MoodyLyrics"

# https://www.kaggle.com/datasets/cakiki/muse-the-musical-sentiment-dataset/data
MuSe = "./muse_v3.csv"

MXM_TRAIN = "./mxm_dataset_train.csv"
MXM_TEST = "./mxm_dataset_test.csv"

# %%
def dig(path, ftype):
    """
    returns list of all files of the specified extension in every recursive subdirectory in a given parent dir
    """
    paths = []
    for dirpath, _, files in os.walk(path):
        paths += [(dirpath + "/" + f) for f in files if f.endswith(ftype)]
    return paths

# %% [markdown]
# ### MillionSongs

# %%
# dig for files
files = dig(MSD, ".h5")
# print example
print(files[1])
# Out:
# ./MillionSongSubset/A/X/X/TRAXXQA128F9301855.h5

# %%
with tables.open_file(files[4053], mode='r') as f:
    print("Artist", h5.get_artist_name(f))
    print("Song", h5.get_title(f))
    print("Album", h5.get_release(f))
    print("Familiarity", h5.get_artist_familiarity(f))
    print("Hotttnesss", h5.get_artist_hotttnesss(f))
    print("Danceability", h5.get_danceability(f))
    print("artistid", h5.get_artist_id(f))
    print("tags", h5.get_artist_mbtags(f))
    print("tags", h5.get_artist_mbtags_count(f))
    print("id", h5.get_track_id(f))
    print('song_id', h5.get_song_id(f))
    print(files[4053])
# Out:
# Artist b'Saosin'
# Song b'Bury Your Head'
# Album b'Saosin EP'
# Familiarity 0.7550771510720238
# Hotttnesss 0.5637637522823244
# Danceability 0.0
# artistid b'ARGO67V1187B9968D2'
# tags [b'post-hardcore' b'alternative rock' b'rock' b'american']
# tags [1 1 1 1]
# id b'TRACFZI128E0795424'
# song_id b'SOCTJIL12A67ADAF3F'
# ./MillionSongSubset/A/C/F/TRACFZI128E0795424.h5

# %% [markdown]
# ### MXM xref MillionSongs

# %%
songs = {}
for x in range(len(files)):
    with tables.open_file(files[x], 'r') as f:
        name = h5.get_artist_name(f).decode('UTF-8')
        title = h5.get_title(f).decode('UTF-8')
        track_id = h5.get_track_id(f).decode('UTF-8')
        songs[track_id] = (name, title)
print("done")
# Out:
# done

# %%
with open(MXM_TRAIN, 'r') as filein, open('mxm_new_train.csv', 'w') as newfile:
    for line in filein:
        cols = line.split(',')
        new_delim = ';'.join(cols[:2]) + ';' + ','.join(cols[2:])
        newfile.write(new_delim)

# %%
mxm = pd.read_csv("mxm_new_train.csv", delimiter=";", header=None, names=['track_ID', 'ID', 'word_counts'])
for x in mxm.values:
    print(eval("{"+x[2]+"}"))
    break
# Out:
# {1: 6, 2: 4, 3: 2, 4: 2, 5: 5, 6: 3, 7: 1, 8: 1, 11: 1, 12: 2, 13: 3, 14: 1, 15: 1, 18: 2, 19: 2, 20: 2, 21: 2, 23: 4, 25: 1, 26: 2, 28: 1, 30: 1, 36: 2, 42: 1, 45: 1, 54: 2, 56: 1, 57: 1, 68: 1, 99: 1, 192: 2, 249: 1, 264: 1, 356: 1, 389: 1, 561: 1, 639: 1, 656: 1, 687: 1, 761: 1, 773: 1, 804: 1, 869: 2, 914: 1, 1035: 1, 1156: 1, 1221: 1, 1287: 1, 1364: 1, 1407: 1, 1533: 2, 1857: 1, 2096: 1, 2117: 1, 2482: 2, 2548: 1, 2705: 1, 2723: 1, 2868: 2, 2992: 2, 3455: 1, 3717: 1, 3851: 1, 4322: 1, 4382: 1, 4613: 1, 4713: 1, 4906: 1}

# %%
mxm = pd.read_csv("mxm_new_train.csv", delimiter=";", header=None, names=['track_ID', 'ID', 'word_counts'])
mxm
# Out:
#                   track_ID       ID
# 0       TRAAAAV128F421A322  4623710  \
# 1       TRAAABD128F429CF47  6477168
# 2       TRAAAED128E0783FAB  2516445
# 3       TRAAAEF128F4273421  3759847
# 4       TRAAAEW128F42930C0  3783760
# ...                    ...      ...
# 210514  TRZZZWS128F429CF87  3080645
# 210515  TRZZZXA128F428ED56  2344272
# 210516  TRZZZXV128F4289747  1417347
# 210517  TRZZZYV128F92E996D  6849828
# 210518  TRZZZYX128F92D32C6   681124
#
#                                               word_counts
# 0       1:6,2:4,3:2,4:2,5:5,6:3,7:1,8:1,11:1,12:2,13:3...
# 1       1:10,3:17,4:8,5:2,6:2,7:1,8:3,9:2,10:3,11:4,12...
# 2       1:28,2:15,3:2,4:12,5:22,6:2,7:2,8:4,9:2,10:1,1...
# 3       1:5,2:4,3:3,4:2,5:1,6:11,9:4,12:9,13:3,15:2,16...
# 4       1:4,4:5,5:7,6:2,7:4,9:1,10:1,11:9,15:1,17:2,20...
# ...                                                   ...
# 210514  6:1,24:9,38:7,42:1,77:4,90:1,112:5,114:4,117:2...
# 210515  1:1,2:13,3:6,4:5,5:4,6:6,9:4,10:4,12:3,13:2,17...
# 210516  1:13,2:3,3:17,4:5,5:9,7:8,8:2,9:1,11:9,15:1,17...
# 210517  1:10,2:6,3:20,5:2,7:30,8:1,9:6,10:3,11:19,12:1...
# 210518  1:4,2:18,4:3,5:6,6:9,7:1,8:5,9:1,10:12,11:2,12...
#
# [210519 rows x 3 columns]

# %%
mxm["Artist"] = None
mxm["Title"] = None
mxm
# Out:
#                   track_ID       ID
# 0       TRAAAAV128F421A322  4623710  \
# 1       TRAAABD128F429CF47  6477168
# 2       TRAAAED128E0783FAB  2516445
# 3       TRAAAEF128F4273421  3759847
# 4       TRAAAEW128F42930C0  3783760
# ...                    ...      ...
# 210514  TRZZZWS128F429CF87  3080645
# 210515  TRZZZXA128F428ED56  2344272
# 210516  TRZZZXV128F4289747  1417347
# 210517  TRZZZYV128F92E996D  6849828
# 210518  TRZZZYX128F92D32C6   681124
#
#                                               word_counts Artist Title
# 0       1:6,2:4,3:2,4:2,5:5,6:3,7:1,8:1,11:1,12:2,13:3...   None  None
# 1       1:10,3:17,4:8,5:2,6:2,7:1,8:3,9:2,10:3,11:4,12...   None  None
# 2       1:28,2:15,3:2,4:12,5:22,6:2,7:2,8:4,9:2,10:1,1...   None  None
# 3       1:5,2:4,3:3,4:2,5:1,6:11,9:4,12:9,13:3,15:2,16...   None  None
# 4       1:4,4:5,5:7,6:2,7:4,9:1,10:1,11:9,15:1,17:2,20...   None  None
# ...                                                   ...    ...   ...
# 210514  6:1,24:9,38:7,42:1,77:4,90:1,112:5,114:4,117:2...   None  None
# 210515  1:1,2:13,3:6,4:5,5:4,6:6,9:4,10:4,12:3,13:2,17...   None  None
# 210516  1:13,2:3,3:17,4:5,5:9,7:8,8:2,9:1,11:9,15:1,17...   None  None
# 210517  1:10,2:6,3:20,5:2,7:30,8:1,9:6,10:3,11:19,12:1...   None  None
# 210518  1:4,2:18,4:3,5:6,6:9,7:1,8:5,9:1,10:12,11:2,12...   None  None
#
# [210519 rows x 5 columns]

# %%
for idx, row in mxm.iterrows():
    track_id = row['track_ID']
    if track_id in songs:
        mxm.at[idx, 'Artist'], mxm.at[idx, 'Title'] = songs[track_id]
mxm
# Out:
#                   track_ID       ID
# 0       TRAAAAV128F421A322  4623710  \
# 1       TRAAABD128F429CF47  6477168
# 2       TRAAAED128E0783FAB  2516445
# 3       TRAAAEF128F4273421  3759847
# 4       TRAAAEW128F42930C0  3783760
# ...                    ...      ...
# 210514  TRZZZWS128F429CF87  3080645
# 210515  TRZZZXA128F428ED56  2344272
# 210516  TRZZZXV128F4289747  1417347
# 210517  TRZZZYV128F92E996D  6849828
# 210518  TRZZZYX128F92D32C6   681124
#
#                                               word_counts        Artist
# 0       1:6,2:4,3:2,4:2,5:5,6:3,7:1,8:1,11:1,12:2,13:3...          None  \
# 1       1:10,3:17,4:8,5:2,6:2,7:1,8:3,9:2,10:3,11:4,12...  The Box Tops
# 2       1:28,2:15,3:2,4:12,5:22,6:2,7:2,8:4,9:2,10:1,1...          None
# 3       1:5,2:4,3:3,4:2,5:1,6:11,9:4,12:9,13:3,15:2,16...      Adam Ant
# 4       1:4,4:5,5:7,6:2,7:4,9:1,10:1,11:9,15:1,17:2,20...          None
# ...                                                   ...           ...
# 210514  6:1,24:9,38:7,42:1,77:4,90:1,112:5,114:4,117:2...          None
# 210515  1:1,2:13,3:6,4:5,5:4,6:6,9:4,10:4,12:3,13:2,17...          None
# 210516  1:13,2:3,3:17,4:5,5:9,7:8,8:2,9:1,11:9,15:1,17...          None
# 210517  1:10,2:6,3:20,5:2,7:30,8:1,9:6,10:3,11:19,12:1...          None
# 210518  1:4,2:18,4:3,5:6,6:9,7:1,8:5,9:1,10:12,11:2,12...          None
#
#                   Title
# 0                  None
# 1             Soul Deep
# 2                  None
# 3       Something Girls
# 4                  None
# ...                 ...
# 210514             None
# 210515             None
# 210516             None
# 210517             None
# 210518             None
#
# [210519 rows x 5 columns]

# %%
mxm.dropna(subset=['Artist'], inplace=True)
mxm.drop(columns=["track_ID", "ID"], inplace=True)
mxm
# Out:
#                                              word_counts
# 1      1:10,3:17,4:8,5:2,6:2,7:1,8:3,9:2,10:3,11:4,12...  \
# 3      1:5,2:4,3:3,4:2,5:1,6:11,9:4,12:9,13:3,15:2,16...
# 5      1:16,2:4,4:1,5:3,6:5,7:5,8:3,9:4,10:3,11:2,12:...
# 11     1:6,2:7,3:3,4:1,5:15,6:10,7:1,8:13,9:1,10:3,11...
# 19     1:6,2:5,3:10,4:4,5:6,6:2,7:6,8:6,9:1,11:2,12:1...
# ...                                                  ...
# 11017  1:21,2:7,3:17,4:7,5:9,6:2,7:8,8:4,9:9,10:1,11:...
# 11022  3:1,4:3,10:1,19:6,22:2,26:1,28:4,30:1,32:1,33:...
# 11023  2:24,4:11,5:8,6:2,9:2,10:2,13:6,16:4,17:5,18:9...
# 11026  1:4,2:10,3:14,4:1,5:8,6:7,7:8,8:6,10:2,11:4,12...
# 11036  1:14,2:5,3:11,4:10,7:19,8:1,9:1,11:1,12:5,14:3...
#
#                        Artist                        Title
# 1                The Box Tops                    Soul Deep
# 3                    Adam Ant              Something Girls
# 5                         Gob               Face the Ashes
# 11           Planet P Project                   Pink World
# 19              Lionel Richie      Tonight Will Be Alright
# ...                       ...                          ...
# 11017        Chantal Chamandy                      Zindegi
# 11022  Mouth Of The Architect      Harboring An Apparition
# 11023           It Dies Today  One the road (to Damnation)
# 11026               Moonspell               The Hanged Man
# 11036     Seventh Day Slumber               Shattered Life
#
# [2350 rows x 3 columns]

# %%
mxm['word_counts'] = mxm['word_counts'].apply(lambda x: eval("{"+x+"}"))
mxm
# Out:
#                                              word_counts
# 1      {1: 10, 3: 17, 4: 8, 5: 2, 6: 2, 7: 1, 8: 3, 9...  \
# 3      {1: 5, 2: 4, 3: 3, 4: 2, 5: 1, 6: 11, 9: 4, 12...
# 5      {1: 16, 2: 4, 4: 1, 5: 3, 6: 5, 7: 5, 8: 3, 9:...
# 11     {1: 6, 2: 7, 3: 3, 4: 1, 5: 15, 6: 10, 7: 1, 8...
# 19     {1: 6, 2: 5, 3: 10, 4: 4, 5: 6, 6: 2, 7: 6, 8:...
# ...                                                  ...
# 11017  {1: 21, 2: 7, 3: 17, 4: 7, 5: 9, 6: 2, 7: 8, 8...
# 11022  {3: 1, 4: 3, 10: 1, 19: 6, 22: 2, 26: 1, 28: 4...
# 11023  {2: 24, 4: 11, 5: 8, 6: 2, 9: 2, 10: 2, 13: 6,...
# 11026  {1: 4, 2: 10, 3: 14, 4: 1, 5: 8, 6: 7, 7: 8, 8...
# 11036  {1: 14, 2: 5, 3: 11, 4: 10, 7: 19, 8: 1, 9: 1,...
#
#                        Artist                        Title
# 1                The Box Tops                    Soul Deep
# 3                    Adam Ant              Something Girls
# 5                         Gob               Face the Ashes
# 11           Planet P Project                   Pink World
# 19              Lionel Richie      Tonight Will Be Alright
# ...                       ...                          ...
# 11017        Chantal Chamandy                      Zindegi
# 11022  Mouth Of The Architect      Harboring An Apparition
# 11023           It Dies Today  One the road (to Damnation)
# 11026               Moonspell               The Hanged Man
# 11036     Seventh Day Slumber               Shattered Life
#
# [2350 rows x 3 columns]

# %%
mxm.to_csv("mxm_train.csv", ";")

# %% [markdown]
# ### MuSe xref MXM

# %%
muse = pd.read_csv(MuSe)
muse.drop(columns=["lastfm_url", "mbid", "spotify_id"], inplace=True)
muse
# Out:
#                                          Title                       Artist
# 0                             'Till I Collapse                       Eminem  \
# 1                                    St. Anger                    Metallica
# 2                                     Speedin'                    Rick Ross
# 3                                 Bamboo Banga                       M.I.A.
# 4                                   Die MF Die                         Dope
# ...                                        ...                          ...
# 89996                                   Battle  Gaby Hoffmann & Jay Duplass
# 89997  Hands Tied to the Roots of a Hemorrhage         Omar Rodriguez-Lopez
# 89998                           Crookfield Zoo                    Ace White
# 89999               Transparent (Full Version)                 Second Chyld
# 90000                                   Unfold             Message To Bears
#
#                                             seeds  number_of_emotion_tags
# 0                                  ['aggressive']                       6  \
# 1                                  ['aggressive']                       8
# 2                                  ['aggressive']                       1
# 3      ['aggressive', 'fun', 'sexy', 'energetic']                      13
# 4                                  ['aggressive']                       7
# ...                                           ...                     ...
# 89996                             ['transparent']                       1
# 89997                             ['transparent']                       4
# 89998                             ['transparent']                       1
# 89999                             ['transparent']                       1
# 90000                             ['translucent']                       2
#
#        valence_tags  arousal_tags  dominance_tags             genre
# 0          4.550000      5.273125        5.690625               rap
# 1          3.710000      5.833000        5.427250             metal
# 2          3.080000      5.870000        5.490000               rap
# 3          6.555071      5.537214        5.691357           hip-hop
# 4          3.771176      5.348235        5.441765             metal
# ...             ...           ...             ...               ...
# 89996      5.370000      3.450000        5.330000               NaN
# 89997      5.797887      4.132254        5.570563  progressive rock
# 89998      5.370000      3.450000        5.330000               NaN
# 89999      5.370000      3.450000        5.330000               NaN
# 90000      3.340000      1.405000        3.500000           ambient
#
# [90001 rows x 8 columns]

# %%
mxm = pd.read_csv("mxm_labels.csv", delimiter=";")
mxm
# Out:
#       Unnamed: 0                                        word_counts
# 0              1  {1: 10, 3: 17, 4: 8, 5: 2, 6: 2, 7: 1, 8: 3, 9...  \
# 1              3  {1: 5, 2: 4, 3: 3, 4: 2, 5: 1, 6: 11, 9: 4, 12...
# 2              5  {1: 16, 2: 4, 4: 1, 5: 3, 6: 5, 7: 5, 8: 3, 9:...
# 3             11  {1: 6, 2: 7, 3: 3, 4: 1, 5: 15, 6: 10, 7: 1, 8...
# 4             19  {1: 6, 2: 5, 3: 10, 4: 4, 5: 6, 6: 2, 7: 6, 8:...
# ...          ...                                                ...
# 2345       11017  {1: 21, 2: 7, 3: 17, 4: 7, 5: 9, 6: 2, 7: 8, 8...
# 2346       11022  {3: 1, 4: 3, 10: 1, 19: 6, 22: 2, 26: 1, 28: 4...
# 2347       11023  {2: 24, 4: 11, 5: 8, 6: 2, 9: 2, 10: 2, 13: 6,...
# 2348       11026  {1: 4, 2: 10, 3: 14, 4: 1, 5: 8, 6: 7, 7: 8, 8...
# 2349       11036  {1: 14, 2: 5, 3: 11, 4: 10, 7: 19, 8: 1, 9: 1,...
#
#                       Artist                        Title
# 0               The Box Tops                    Soul Deep
# 1                   Adam Ant              Something Girls
# 2                        Gob               Face the Ashes
# 3           Planet P Project                   Pink World
# 4              Lionel Richie      Tonight Will Be Alright
# ...                      ...                          ...
# 2345        Chantal Chamandy                      Zindegi
# 2346  Mouth Of The Architect      Harboring An Apparition
# 2347           It Dies Today  One the road (to Damnation)
# 2348               Moonspell               The Hanged Man
# 2349     Seventh Day Slumber               Shattered Life
#
# [2350 rows x 4 columns]

# %%
mxmuse = pd.merge(mxm, muse[['Title', 'Artist', 'valence_tags', 'arousal_tags', 'dominance_tags', 'seeds']], on=['Artist', 'Title'], how='inner')
mxmuse.drop(columns=["Unnamed: 0"], inplace=True)
mxmuse
# Out:
#     Unnamed: 0                                        word_counts
# 0           66  {6: 7, 7: 2, 24: 1, 38: 3, 42: 3, 47: 8, 77: 4...  \
# 1          117  {1: 32, 2: 16, 3: 20, 4: 21, 5: 3, 6: 5, 7: 22...
# 2          172  {1: 10, 2: 8, 3: 1, 4: 8, 5: 7, 6: 3, 7: 2, 8:...
# 3          227  {1: 17, 2: 17, 3: 15, 4: 26, 5: 8, 6: 19, 7: 4...
# 4          250  {2: 11, 3: 2, 4: 6, 5: 2, 6: 8, 7: 3, 10: 6, 1...
# ..         ...                                                ...
# 81       10550  {1: 12, 2: 16, 3: 14, 4: 24, 5: 8, 9: 12, 10: ...
# 82       10552  {1: 6, 2: 5, 3: 6, 4: 2, 5: 4, 6: 1, 7: 9, 8: ...
# 83       10685  {1: 2, 2: 8, 3: 2, 4: 5, 5: 5, 6: 5, 7: 4, 8: ...
# 84       10907  {1: 5, 2: 8, 3: 5, 4: 2, 5: 11, 6: 1, 7: 3, 8:...
# 85       10973  {1: 10, 2: 24, 3: 7, 4: 4, 5: 7, 6: 10, 7: 1, ...
#
#             Artist                           Title  valence_tags
# 0      Soda Stereo                 Entre Caníbales      3.130000  \
# 1      Boyz II Men                  On Bended Knee      6.472533
# 2        Pearl Jam                      Inside Job      6.470000
# 3        Busdriver  (Bloody Paw On The) Kill Floor      2.540000
# 4          Orbital                      Illuminate      5.628889
# ..             ...                             ...           ...
# 81          22-20s                         Hold On      3.033333
# 82          Weezer                 Mykel And Carli      6.586408
# 83  Scott Matthews                   City Headache      6.024516
# 84      K's Choice                  20.000 Seconds      4.252000
# 85     The Killers            A Dustland Fairytale      6.565763
#
#     arousal_tags  dominance_tags                     seeds
# 0       2.997500        3.212500             ['nostalgic']
# 1       4.509067        5.800933              ['romantic']
# 2       3.962609        5.741304                  ['epic']
# 3       2.045000        2.305000           ['apocalyptic']
# 4       3.875111        4.814222               ['driving']
# ..           ...             ...                       ...
# 81      4.130000        4.336667              ['brooding']
# 82      4.900583        5.632233  ['bittersweet', 'sweet']
# 83      3.301613        6.112258                 ['quiet']
# 84      3.878000        4.700000                 ['light']
# 85      4.728475        5.585932                  ['epic']
#
# [86 rows x 8 columns]

# %%
mxmuse.to_csv("mxmuse.csv", ";")

# %% [markdown]
# ### MoodyLyrics xref MXM

# %%
moody = pd.read_excel(MOODY + "/ml_raw.xlsx", sheet_name="MoodyLyrics_no_lyrics_publish", header=15)
moody
# Out:
#        Index           Artist               Title     Mood
# 0        ML1            Usher  There Goes My Baby  relaxed
# 1        ML2         Da'Ville          On My Mind  relaxed
# 2        ML3          Rihanna       Rockstar 101   relaxed
# 3        ML4       J. Holiday                 Bed  relaxed
# 4        ML5  Morgan Heritage   Don't Haffi Dread    angry
# ...      ...              ...                 ...      ...
# 2590  ML2591           Slayer    Fight Till Death    angry
# 2591  ML2592          Anthrax    Among the Living    angry
# 2592  ML2593            Opeth       Heir Apparent      sad
# 2593  ML2594        Sepultura           Territory    angry
# 2594  ML2595      Bing Crosby       Sweet Leilani  relaxed
#
# [2595 rows x 4 columns]

# %%
mxmoody = pd.merge(mxm, moody[['Artist', 'Title', 'Mood']], on=['Artist', 'Title'], how='inner')
mxmoody
# Out:
#                                           word_counts
# 0   {1: 5, 2: 4, 3: 3, 4: 2, 5: 1, 6: 11, 9: 4, 12...  \
# 1   {2: 5, 4: 1, 5: 2, 6: 3, 7: 1, 8: 2, 9: 1, 10:...
# 2   {1: 3, 2: 4, 3: 16, 4: 1, 6: 1, 8: 2, 9: 4, 10...
# 3   {1: 2, 2: 19, 3: 8, 4: 9, 5: 14, 6: 2, 7: 2, 8...
# 4   {1: 11, 2: 9, 3: 7, 4: 1, 5: 4, 6: 4, 7: 9, 8:...
# ..                                                ...
# 91  {1: 15, 2: 10, 3: 18, 4: 5, 5: 10, 6: 4, 7: 36...
# 92  {1: 29, 2: 2, 3: 34, 4: 2, 5: 5, 6: 1, 9: 5, 1...
# 93  {1: 17, 2: 8, 3: 1, 4: 2, 5: 1, 6: 16, 7: 9, 8...
# 94  {1: 20, 2: 7, 3: 19, 4: 6, 5: 11, 7: 18, 8: 1,...
# 95  {6: 1, 23: 1, 111: 1, 501: 1, 545: 1, 578: 1, ...
#
#                      Artist                                     Title     Mood
# 0                  Adam Ant                           Something Girls  relaxed
# 1      The Suicide Machines                  Burning In The Aftermath    angry
# 2               Dean Martin                    Until You Love Someone    happy
# 3        Panic At The Disco         Northern Downpour (Album Version)      sad
# 4               Robben Ford                    Something For The Pain    angry
# ..                      ...                                       ...      ...
# 91              Descendents                                     Cheer    happy
# 92                 Deftones  No Ordinary Love (Remastered LP Version)    happy
# 93                   Foghat                           Dead End Street      sad
# 94  Queens Of The Stone Age                Everybody's Gonna Be Happy    happy
# 95              Wyclef Jean                           Midnight Lovers      sad
#
# [96 rows x 4 columns]

# %%
mxmoody.to_csv("./mxmoody.csv", sep=";")
